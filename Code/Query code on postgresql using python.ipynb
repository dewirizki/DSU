# %%
import pandas.io.sql as sqlio
import psycopg2 as pg
import pandas as pd

# %%
conn = pg.connect(database="DSU",
                 user="postgres",
                 password="Frzk$28dw",
                 host="localhost",
                 port="5433")

# %%
def run(query):
    df = pd.read_sql(query, conn)
    return df

cur = conn.cursor()

# %%
run("""
SELECT * FROM _offices
ORDER BY country, state, city;
""")
# Out:
#    officecode           city             phone              addressline1  \
# 0           6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 1           4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 2           5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 3           7         London  +44 20 7877 2041       25 Old Broad Street
# 4           1  San Francisco   +1 650 219 4782         100 Market Street
# 5           2         Boston   +1 215 837 0825          1550 Court Place
# 6           3            NYC   +1 212 555 3000      523 East 53rd Street
#
#   addressline2       state    country postalcode territory
# 0     Floor #2              Australia   NSW 2010      APAC
# 1                              France      75017      EMEA
# 2               Chiyoda-Ku      Japan   102-8578     Japan
# 3      Level 7                     UK   EC2N 1HN      EMEA
# 4    Suite 300          CA        USA      94080        NA
# ...

# %%
run("""
SELECT COUNT (*) AS "AmountOfEmployee"
FROM _employees;
""")
# Out:
#    AmountOfEmployee
# 0                23

# %%
run("""
SELECT SUM (amount) AS "TotalPayment"
FROM _payments;
""")
# Out:
#    TotalPayment
# 0    8853839.23

# %%
run("""
SELECT amount
FROM _payments
WHERE amount > 100000;
""")
# Out:
#       amount
# 0  101244.59
# 1  111654.40
# 2  116208.40
# 3  120166.58
# 4  105743.00

# %%
run("""
SELECT *
FROM _products
ORDER BY productline;
""")
# Out:
#     productcode                                productname   productline  \
# 0      S18_2238             1998 Chrysler Plymouth Prowler  Classic Cars
# 1      S10_1949                   1952 Alpine Renault 1300  Classic Cars
# 2      S10_4757                        1972 Alfa Romeo GTA  Classic Cars
# 3      S10_4962                     1962 LanciaA Delta 16V  Classic Cars
# 4      S12_1099                          1968 Ford Mustang  Classic Cars
# ..          ...                                        ...           ...
# 105    S24_2022  1938 Cadillac V-16 Presidential Limousine  Vintage Cars
# 106    S24_3420                  1937 Horch 930V Limousine  Vintage Cars
# 107    S18_3136        18th Century Vintage Horse Carriage  Vintage Cars
# 108    S24_3969           1936 Mercedes Benz 500k Roadster  Vintage Cars
# 109    S18_3320                   1917 Maxwell Touring Car  Vintage Cars
#
#     productscale            productvendor  \
# 0           1:18     Gearbox Collectibles
# ...

# %%
run("""
SELECT productline,
COUNT (productname) AS "TotalProduct"
FROM _products
GROUp BY productline;
""")
# Out:
#         productline  TotalProduct
# 0      Classic Cars            38
# 1            Trains             3
# 2            Planes            12
# 3  Trucks and Buses            11
# 4      Vintage Cars            24
# 5       Motorcycles            13
# 6             Ships             9

# %%
run("""
SELECT MIN(amount) AS "Minimum_Payment"
FROM _payments;
""")
# Out:
#    Minimum_Payment
# 0           615.45

# %%
run("""
SELECT quantityordered*priceeach AS "TotalOrder"
FROM _orderdetails
WHERE quantityordered*priceeach > 5000;
""")
# Out:
#      TotalOrder
# 0       5571.80
# 1       5026.14
# 2       6392.00
# 3       8434.52
# 4       5072.71
# ..          ...
# 405     5847.10
# 406    10072.00
# 407     5960.36
# 408     5859.00
# 409     6261.71
#
# [410 rows x 1 columns]
